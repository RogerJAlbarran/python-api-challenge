# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
# %run ./api_keys.ipynb

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
new_lats = []
new_longs = []
cities = []
countries = []
temp = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    #countries.append(country)
    # If the city is unique, then add it to a our cities list
   #if country not in countries:
     #   countries.append(country)
    if city not in cities:
        cities.append(city)
        countries.append(country)
        new_lats.append(lat_lng[0])
        new_longs.append(lat_lng[1])
   # Print the city count to confirm sufficient count

print(len(cities))
print(len(countries))
print(len(new_lats))
print(len(new_longs))
# Out:
# 608
# 608
# 608
# 608

# %%
# Use citipy to define city and country from coordinates
# Create a new df

Weather_now_df = pd.DataFrame({"Latitude": new_lats, "Longitude": new_longs, "City":cities})

# %%
Weather_now_df.head()
# Out:
#     Latitude   Longitude        City
# 0 -41.007482  -50.141060       rocha
# 1  80.916761  -83.707804     qaanaaq
# 2 -40.630030 -146.501902     mataura
# 3 -19.309935  172.126292     isangel
# 4  23.609815  -58.819782  codrington

# %%
api_key = "08b2b3933f6b578b05842b04d5e18bfb"


url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=rocha
# Processing Record 2 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=qaanaaq
# Processing Record 3 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mataura
# Processing Record 4 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=isangel
# Processing Record 5 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=codrington
# Processing Record 6 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ribeira grande
# Processing Record 7 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=verkhoyansk
# Processing Record 8 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cape town
# Processing Record 9 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kahului
# Processing Record 10 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kodiak
# Processing Record 11 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=nantucket
# Processing Record 12 | Iralaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=iralaya
# Processing Record 13 | Igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=igrim
# Processing Record 14 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=esperance
# Processing Record 15 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ayan
# Processing Record 16 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=belyy yar
# Processing Record 17 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chuy
# Processing Record 18 | High Prairie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=high prairie
# Processing Record 19 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=atuona
# City not found. Skipping...
# Processing Record 20 | Kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kattivakkam
# Processing Record 21 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=matara
# Processing Record 22 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=faanui
# Processing Record 23 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lorengau
# Processing Record 24 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=fort nelson
# Processing Record 25 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hilo
# Processing Record 26 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=longyearbyen
# Processing Record 27 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bambous virieux
# Processing Record 28 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=jamestown
# Processing Record 29 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=new norfolk
# Processing Record 30 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hami
# Processing Record 31 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=albany
# Processing Record 32 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=busselton
# City not found. Skipping...
# Processing Record 33 | Ushumun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ushumun
# Processing Record 34 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tasiilaq
# Processing Record 35 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chokurdakh
# Processing Record 36 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ambilobe
# Processing Record 37 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ushuaia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 | Chalmette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chalmette
# Processing Record 39 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kavieng
# Processing Record 40 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=fortuna
# Processing Record 41 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=rikitea
# Processing Record 42 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hobart
# Processing Record 43 | San Pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san pedro
# Processing Record 44 | Nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=nanakuli
# Processing Record 45 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=saskylakh
# Processing Record 46 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=khatanga
# Processing Record 47 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=vaini
# Processing Record 48 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hermanus
# Processing Record 49 | Atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=atambua
# Processing Record 50 | Moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=moindou
# Processing Record 51 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=berlevag
# Processing Record 52 | Beberibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=beberibe
# Processing Record 53 | Pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=pacifica
# Processing Record 54 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hofn
# City not found. Skipping...
# Processing Record 55 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=geraldton
# Processing Record 56 | Wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=wajima
# Processing Record 57 | Placerville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=placerville
# Processing Record 58 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bredasdorp
# Processing Record 59 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bluff
# Processing Record 60 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kaeo
# Processing Record 61 | Turochak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=turochak
# Processing Record 62 | Arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=arman
# Processing Record 63 | San Luis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san luis
# Processing Record 64 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=upernavik
# Processing Record 65 | Cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cururupu
# Processing Record 66 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=narsaq
# Processing Record 67 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=fairbanks
# Processing Record 68 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=punta arenas
# Processing Record 69 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mount gambier
# Processing Record 70 | Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chumikan
# Processing Record 71 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ruteng
# Processing Record 72 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ponta do sol
# Processing Record 73 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bethel
# Processing Record 74 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lasa
# Processing Record 75 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=severo-kurilsk
# Processing Record 76 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ahipara
# Processing Record 77 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=beyneu
# City not found. Skipping...
# Processing Record 78 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=nikolskoye
# Processing Record 79 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=baykit
# Processing Record 80 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ilhabela
# Processing Record 81 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kaitangata
# Processing Record 82 | Totness
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=totness
# Processing Record 83 | Chotila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chotila
# Processing Record 84 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kupang
# Processing Record 85 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=santa cruz
# Processing Record 86 | Huari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=huari
# Processing Record 87 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=puerto ayora
# City not found. Skipping...
# Processing Record 88 | Ferrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ferrol
# Processing Record 89 | Miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=miri
# Processing Record 90 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bonavista
# Processing Record 91 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=klaksvik
# Processing Record 92 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=coihaique
# Processing Record 93 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=los llanos de aridane
# Processing Record 94 | Alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=alihe
# Processing Record 95 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kapaa
# Processing Record 96 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=svetlogorsk
# Processing Record 97 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=thompson
# Processing Record 98 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=davila
# Processing Record 99 | Waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=waddan
# Processing Record 100 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=georgetown
# Processing Record 101 | Derby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=derby
# City not found. Skipping...
# Processing Record 102 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=pevek
# Processing Record 103 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tuktoyaktuk
# Processing Record 104 | Sattahip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sattahip
# Processing Record 105 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cap malheureux
# Processing Record 106 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=constitucion
# Processing Record 107 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=butaritari
# Processing Record 108 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mount isa
# Processing Record 109 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=arraial do cabo
# Processing Record 110 | Lishui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lishui
# Processing Record 111 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=taltal
# Processing Record 112 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=port alfred
# Processing Record 113 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=batemans bay
# City not found. Skipping...
# Processing Record 114 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sola
# Processing Record 115 | Mangit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mangit
# Processing Record 116 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=souillac
# Processing Record 117 | Nisia Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=nisia floresta
# City not found. Skipping...
# Processing Record 118 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tiznit
# Processing Record 119 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=barrow
# Processing Record 120 | Datagon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=datagon
# City not found. Skipping...
# Processing Record 121 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=carnarvon
# Processing Record 122 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kruisfontein
# City not found. Skipping...
# Processing Record 123 | Nagapattinam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=nagapattinam
# Processing Record 124 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=caravelas
# Processing Record 125 | Jardim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=jardim
# Processing Record 126 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=coquimbo
# Processing Record 127 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=avarua
# Processing Record 128 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ca mau
# Processing Record 129 | Salamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=salamina
# Processing Record 130 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ancud
# Processing Record 131 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sitka
# Processing Record 132 | Dzhebariki-Khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=dzhebariki-khaya
# Processing Record 133 | Bozeman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bozeman
# Processing Record 134 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=puerto escondido
# Processing Record 135 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=port elizabeth
# Processing Record 136 | Banamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=banamba
# Processing Record 137 | Karmala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=karmala
# Processing Record 138 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mar del plata
# Processing Record 139 | San Carlos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san carlos
# Processing Record 140 | Ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=ulaangom
# Processing Record 141 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=grindavik
# City not found. Skipping...
# Processing Record 142 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bathsheba
# Processing Record 143 | Fagernes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=fagernes
# Processing Record 144 | Atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=atikokan
# Processing Record 145 | Giddalur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=giddalur
# City not found. Skipping...
# Processing Record 146 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cockburn town
# Processing Record 147 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san andres
# Processing Record 148 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sao joao da barra
# Processing Record 149 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hambantota
# Processing Record 150 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=iqaluit
# Processing Record 151 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=poum
# Processing Record 152 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tazovskiy
# Processing Record 153 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=yellowknife
# Processing Record 154 | Villa Bruzual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=villa bruzual
# Processing Record 155 | Guatire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=guatire
# City not found. Skipping...
# Processing Record 156 | Mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mumford
# Processing Record 157 | Mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mecca
# Processing Record 158 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=namie
# Processing Record 159 | Manzhouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=manzhouli
# Processing Record 160 | Sabzevar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sabzevar
# Processing Record 161 | Rensvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=rensvik
# Processing Record 162 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=vila velha
# Processing Record 163 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tilichiki
# Processing Record 164 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=port blair
# Processing Record 165 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=makakilo city
# City not found. Skipping...
# Processing Record 166 | Soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=soyo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 167 | Santiago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=santiago
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 168 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=pangnirtung
# Processing Record 169 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kalmunai
# Processing Record 170 | Alto Araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=alto araguaia
# Processing Record 171 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=la ronge
# Processing Record 172 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cidreira
# Processing Record 173 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=dikson
# Processing Record 174 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hithadhoo
# Processing Record 175 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=castro
# Processing Record 176 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=half moon bay
# Processing Record 177 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=husavik
# Processing Record 178 | Chimay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=chimay
# Processing Record 179 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=shelburne
# City not found. Skipping...
# Processing Record 180 | Mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mildura
# Processing Record 181 | Tete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tete
# Processing Record 182 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=dingle
# Processing Record 183 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hirara
# Processing Record 184 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=margate
# Processing Record 185 | Limon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=limon
# Processing Record 186 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=praia
# Processing Record 187 | Rojhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=rojhan
# Processing Record 188 | Terney
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=terney
# Processing Record 189 | La Paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=la paz
# Processing Record 190 | Grong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=grong
# Processing Record 191 | Katubao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=katubao
# Processing Record 192 | Paramonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=paramonga
# Processing Record 193 | Bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bagdarin
# Processing Record 194 | San Juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san juan
# Processing Record 195 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lompoc
# Processing Record 196 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=portland
# Processing Record 197 | Bulungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=bulungu
# City not found. Skipping...
# Processing Record 198 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lavrentiya
# Processing Record 199 | Callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=callaway
# City not found. Skipping...
# Processing Record 200 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sao filipe
# Processing Record 201 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=itarema
# City not found. Skipping...
# Processing Record 202 | Lavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lavara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 203 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=meulaboh
# Processing Record 204 | Sao Joao do Piaui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sao joao do piaui
# Processing Record 205 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=westport
# Processing Record 206 | Moen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=moen
# Processing Record 207 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=manokwari
# Processing Record 208 | Naryan-Mar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=naryan-mar
# Processing Record 209 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lebu
# Processing Record 210 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=guerrero negro
# Processing Record 211 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=lazaro cardenas
# Processing Record 212 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=clyde river
# Processing Record 213 | Sfantu Gheorghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sfantu gheorghe
# Processing Record 214 | Gympie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=gympie
# Processing Record 215 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=cayenne
# Processing Record 216 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=victoria
# Processing Record 217 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=san quintin
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 218 | Corner Brook
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=corner brook
# City not found. Skipping...
# Processing Record 219 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=gat
# Processing Record 220 | Prescott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=prescott
# Processing Record 221 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=waingapu
# Processing Record 222 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=quatre cocos
# Processing Record 223 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=hovd
# Processing Record 224 | Pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=pingliang
# Processing Record 225 | Asmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=asmar
# Processing Record 226 | Galanta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=galanta
# Processing Record 227 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=mahebourg
# Processing Record 228 | Suratgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=suratgarh
# Processing Record 229 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sobolevo
# Processing Record 230 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=tuatapere
# Processing Record 231 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=deputatskiy
# Processing Record 232 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=jacareacanga
# Processing Record 233 | Wanlaweyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=wanlaweyn
# Processing Record 234 | Stratford-upon-Avon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=stratford-upon-avon
# City not found. Skipping...
# Processing Record 235 | Kurchum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=kurchum
# Processing Record 236 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=provideniya
# Processing Record 237 | Sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=sabang
# Processing Record 238 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=08b2b3933f6b578b05842b04d5e18bfb&q=torbay
